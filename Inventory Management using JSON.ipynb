# %% [markdown]
# #  PRODUCTS REPORT

# %%
record= {301 : {"Name": "Horlicks", "Price": 200, "Quantity" : 100,"Company" : "Unilever", "Best Before" : "5 months"},
        302 : {"Name": "Oats",  "Price": 180, "Quantity" : 100, "Company" : "Quaker Oats", "Best Before" : "6 months"},
        303: {"Name": "Diary Milk", "Price": 20, "Quantity" : 200, "Company" : "Cadbury", "Best Before" : "5 months"},
        304: {"Name": "Peanut butter", "Price": 300, "Quantity" : 100,  "Company" : "Pintola", "Best Before" : "5 months"},
        305: {"Name": "Milk Powder" , "Price": 30, "Quantity" : 25 , "Company" : "Amul", "Best Before" : "2 months"},
        306: {"Name": "50-50", "Price": 10, "Quantity" : 50, "Company" : "Parle","Best Before" : "5 months"},
        307: {"Name": "Gulab Jamun", "Price": 20, "Quantity" : 20, "Company" : "MTR","Best Before" : "NA"},
        308: {"Name": "Kulfi" , "Price": 20, "Quantity" : 30, "Company" : "Nestle","Best Before" : "NA"},
        309: {"Name": "Bourbon", "Price": 10, "Quantity" : 20, "Company" : "Britania","Best Before" : "5 months"},
        310: {"Name": "Krackjack", "Price": 10, "Quantity" : 20, "Company" : "Parle","Best Before" : "5 months"},
        311 : {"Name": "Milky Bar" , "Price": 20, "Quantity" : 1, "Company" : "Nestle","Best Before" : "5 months"},
        312 : {"Name": "Milo", "Price": 15, "Quantity" : 10, "Company" : "Nestle","Best Before" : "3 months"},
        313: {"Name": "Kit Kat" , "Price": 10, "Quantity" : 20, "Company" : "Nestle", "Best Before" : "3 months"},
        314: {"Name": "Nestea", "Price": 20,"Quantity" : 10, "Company" : "Nestle","Best Before" : "5 months"},
        315: {"Name": "Sunfeast", "Price": 10, "Quantity" : 1, "Company" : "ITC", "Best Before" : "4 months"},
        316: {"Name": "20-20", "Price": 10,"Quantity" : 20, "Company" : "Parle", "Best Before" : "3 month"},
        317: {"Name": "Marie", "Price": 10, "Quantity" : 20, "Company" : "Parle", "Best Before" : "3 month"},
        318: {"Name": "FullToss", "Price": 10, "Quantity" : 20, "Company" : "Parle", "Best Before" : "1 month"},
        319: {"Name": "kismi" , "Price": 10, "Quantity" : 20, "Company" : "Parle", "Best Before" : "1 month"},
        320: {"Name": "Poppins", "Price": 10, "Quantity" : 15, "Company" : "Parle", "Best Before" : "1 month"},
        321 : {"Name": "Cattle Feed" , "Price": 50, "Quantity" : 15, "Company" : "Amul", "Best Before" : "1 month"},
        322 : {"Name": "Panchamrit", "Price": 20, "Quantity" : 20, "Company" : "Amul", "Best Before" : "3 months"},
        323: {"Name": "Happy Treats", "Price": 20, "Quantity" : 10, "Company" : "Amul",  "Best Before" : "1 month"},
        324: {"Name": "Bar-One", "Price": 15, "Quantity" : 10, "Company" : "Nestle", "Best Before" : "NA"},
        325: {"Name": "Dahi", "Price": 20, "Quantity" : 10, "Company" : "Nestle", "Best Before" : "NA"},
        326: {"Name": "Happy Happy", "Price":10, "Quantity" : 20, "Company" : "Parle", "Best Before" : "3 months"},
        327: {"Name": "Bread Spreads", "Price": 35, "Quantity" : 15, "Company" : "Amul", "Best Before" : "NA"},
        328: {"Name": "icecream", "Price": 30, "Quantity" : 50, "Company" : "Arun", "Best Before" : "NA"},
        329: {"Name": "Cheese", "Price": 30, "Quantity" : 10, "Company" : "Amul", "Best Before" : "NA"},
        330: {"Name": "Paneer", "Price": 20, "Quantity" : 10, "Company" : "Amul", "Best Before" : "NA"}}

# %%
record
# Out:
# {301: {'Name': 'Horlicks',
#   'Price': 200,
#   'Quantity': 100,
#   'Company': 'Unilever',
#   'Best Before': '5 months'},
#  302: {'Name': 'Oats',
#   'Price': 180,
#   'Quantity': 100,
#   'Company': 'Quaker Oats',
#   'Best Before': '6 months'},
#  303: {'Name': 'Diary Milk',
#   'Price': 20,
#   'Quantity': 200,
#   'Company': 'Cadbury',
#   'Best Before': '5 months'},
#  304: {'Name': 'Peanut butter',
#   'Price': 300,
#   'Quantity': 100,
#   'Company': 'Pintola',
#   'Best Before': '5 months'},
#  305: {'Name': 'Milk Powder',
#   'Price': 30,
#   'Quantity': 25,
#   'Company': 'Amul',
#   'Best Before': '2 months'},
#  306: {'Name': '50-50',
#   'Price': 10,
#   'Quantity': 50,
#   'Company': 'Parle',
#   'Best Before': '5 months'},
#  307: {'Name': 'Gulab Jamun',
#   'Price': 20,
#   'Quantity': 20,
#   'Company': 'MTR',
#   'Best Before': 'NA'},
#  308: {'Name': 'Kulfi',
#   'Price': 20,
#   'Quantity': 30,
#   'Company': 'Nestle',
#   'Best Before': 'NA'},
# ...

# %%
import json

js = json.dumps(record)

# %%
js
# Out:
# '{"301": {"Name": "Horlicks", "Price": 200, "Quantity": 100, "Company": "Unilever", "Best Before": "5 months"}, "302": {"Name": "Oats", "Price": 180, "Quantity": 100, "Company": "Quaker Oats", "Best Before": "6 months"}, "303": {"Name": "Diary Milk", "Price": 20, "Quantity": 200, "Company": "Cadbury", "Best Before": "5 months"}, "304": {"Name": "Peanut butter", "Price": 300, "Quantity": 100, "Company": "Pintola", "Best Before": "5 months"}, "305": {"Name": "Milk Powder", "Price": 30, "Quantity": 25, "Company": "Amul", "Best Before": "2 months"}, "306": {"Name": "50-50", "Price": 10, "Quantity": 50, "Company": "Parle", "Best Before": "5 months"}, "307": {"Name": "Gulab Jamun", "Price": 20, "Quantity": 20, "Company": "MTR", "Best Before": "NA"}, "308": {"Name": "Kulfi", "Price": 20, "Quantity": 30, "Company": "Nestle", "Best Before": "NA"}, "309": {"Name": "Bourbon", "Price": 10, "Quantity": 20, "Company": "Britania", "Best Before": "5 months"}, "310": {"Name": "Krackjack", "Price": 10
# ...

# %%
fd = open("record.json",'w')
fd.write(js)
fd.close()

# %%
file = open("record.json",'r')
r = file.read()
file.close()

record = json.loads(r)

# %% [markdown]
# # Adding New Products

# %%
prod_id = input("Enter product id: ")
name = str(input("Enter product name: "))
price = str(input("Enter product price: "))
quantity = int(input("Enter quantity: "))
company = str(input("Enter Company name: "))
best_before = str(input("Enter best before: "))
record[prod_id] = {"Name":name,"Price":price,"Quantity":quantity,"Company":company,"Best Before":best_before}
js = json.dumps(record)
fd = open("record.json",'w') 
fd.write(js)
fd.close()
# Out:
# Enter product id: 331
# Enter product name: oreo
# Enter product price: 10
# Enter quantity: 20
# Enter Company name: ITC
# Enter best before: 1 months

# %%
record
# Out:
# {'301': {'Name': 'Horlicks',
#   'Price': 200,
#   'Quantity': 100,
#   'Company': 'Unilever',
#   'Best Before': '5 months'},
#  '302': {'Name': 'Oats',
#   'Price': 180,
#   'Quantity': 100,
#   'Company': 'Quaker Oats',
#   'Best Before': '6 months'},
#  '303': {'Name': 'Diary Milk',
#   'Price': 20,
#   'Quantity': 200,
#   'Company': 'Cadbury',
#   'Best Before': '5 months'},
#  '304': {'Name': 'Peanut butter',
#   'Price': 300,
#   'Quantity': 100,
#   'Company': 'Pintola',
#   'Best Before': '5 months'},
#  '305': {'Name': 'Milk Powder',
#   'Price': 30,
#   'Quantity': 25,
#   'Company': 'Amul',
#   'Best Before': '2 months'},
#  '306': {'Name': '50-50',
#   'Price': 10,
#   'Quantity': 50,
#   'Company': 'Parle',
#   'Best Before': '5 months'},
#  '307': {'Name': 'Gulab Jamun',
#   'Price': 20,
#   'Quantity': 20,
#   'Company': 'MTR',
#   'Best Before': 'NA'},
#  '308': {'Name': 'Kulfi',
#   'Price': 20,
#   'Quantity': 30,
#   'Company': 'Nestle',
# ...

# %% [markdown]
# # Adding multiple products

# %%
n = int(input("Enter the number of products to be added: "))
for i in range(n):
  prod_id = input("Enter product id: ")
  name = str(input("Enter product name: "))
  price = str(input("Enter product price: "))
  quantity = int(input("Enter quantity: "))
  company = str(input("Enter Company name: "))
  best_before = str(input("Enter best before: "))
  record[prod_id] = {"Name":name,"Price":price,"Quantity":quantity,"Company":company,"Best Before":best_before}
  js = json.dumps(record)
  fd = open("record.json",'w') 
  fd.write(js)
  fd.close()
# Out:
# Enter the number of products to be added: 2
# Enter product id: 332
# Enter product name: kissan jam
# Enter product price: 10
# Enter quantity: 20
# Enter Company name: unilever
# Enter best before: 1 month
# Enter product id: 333
# Enter product name: pencil
# Enter product price: 5
# Enter quantity: 20
# Enter Company name: Apsara
# Enter best before: NA

# %%
file = open("record.json",'r')
r = file.read()
file.close()
record = json.loads(r)

# %%
record
# Out:
# {'301': {'Name': 'Horlicks',
#   'Price': 200,
#   'Quantity': 100,
#   'Company': 'Unilever',
#   'Best Before': '5 months'},
#  '302': {'Name': 'Oats',
#   'Price': 180,
#   'Quantity': 100,
#   'Company': 'Quaker Oats',
#   'Best Before': '6 months'},
#  '303': {'Name': 'Diary Milk',
#   'Price': 20,
#   'Quantity': 200,
#   'Company': 'Cadbury',
#   'Best Before': '5 months'},
#  '304': {'Name': 'Peanut butter',
#   'Price': 300,
#   'Quantity': 100,
#   'Company': 'Pintola',
#   'Best Before': '5 months'},
#  '305': {'Name': 'Milk Powder',
#   'Price': 30,
#   'Quantity': 25,
#   'Company': 'Amul',
#   'Best Before': '2 months'},
#  '306': {'Name': '50-50',
#   'Price': 10,
#   'Quantity': 50,
#   'Company': 'Parle',
#   'Best Before': '5 months'},
#  '307': {'Name': 'Gulab Jamun',
#   'Price': 20,
#   'Quantity': 20,
#   'Company': 'MTR',
#   'Best Before': 'NA'},
#  '308': {'Name': 'Kulfi',
#   'Price': 20,
#   'Quantity': 30,
#   'Company': 'Nestle',
# ...

# %% [markdown]
# # To remove the products from list

# %%
id = str(input("Enter the product id to delete: "))
if id in record:
  del record[id]
  print("\nSuccessfully Deleted ",id)
else:
  print("Invalid ID")
# Out:
# Enter the product id to delete: 333
#
# Successfully Deleted  333

# %%
record
# Out:
# {'301': {'Name': 'Horlicks',
#   'Price': 200,
#   'Quantity': 100,
#   'Company': 'Unilever',
#   'Best Before': '5 months'},
#  '302': {'Name': 'Oats',
#   'Price': 180,
#   'Quantity': 100,
#   'Company': 'Quaker Oats',
#   'Best Before': '6 months'},
#  '303': {'Name': 'Diary Milk',
#   'Price': 20,
#   'Quantity': 200,
#   'Company': 'Cadbury',
#   'Best Before': '5 months'},
#  '304': {'Name': 'Peanut butter',
#   'Price': 300,
#   'Quantity': 100,
#   'Company': 'Pintola',
#   'Best Before': '5 months'},
#  '305': {'Name': 'Milk Powder',
#   'Price': 30,
#   'Quantity': 25,
#   'Company': 'Amul',
#   'Best Before': '2 months'},
#  '306': {'Name': '50-50',
#   'Price': 10,
#   'Quantity': 50,
#   'Company': 'Parle',
#   'Best Before': '5 months'},
#  '307': {'Name': 'Gulab Jamun',
#   'Price': 20,
#   'Quantity': 20,
#   'Company': 'MTR',
#   'Best Before': 'NA'},
#  '308': {'Name': 'Kulfi',
#   'Price': 20,
#   'Quantity': 30,
#   'Company': 'Nestle',
# ...

# %% [markdown]
# # Upadating the details of products

# %%
prod_id = input("Enter product id to update: ")
print("\nEnter new details\n")
name = str(input("Enter product name: "))
price = str(input("Enter product price: "))
quantity = int(input("Enter quantity: "))
company = str(input("Enter Company name: "))
best_before = str(input("Enter best before: "))
record[prod_id] = {"Name":name,"Price":price,"Quantity":quantity,"Company":company,"Best Before":best_before}
js = json.dumps(record)
fd = open("record.json",'w') 
fd.write(js)
fd.close()
print("\nSuccessfully updated")
# Out:
# Enter product id to update: 333
#
# Enter new details
#
# Enter product name: Red label
# Enter product price: 30
# Enter quantity: 20
# Enter Company name: Brook bond
# Enter best before: 2 months
#
# Successfully updated

# %%
record
# Out:
# {'301': {'Name': 'Horlicks',
#   'Price': 200,
#   'Quantity': 100,
#   'Company': 'Unilever',
#   'Best Before': '5 months'},
#  '302': {'Name': 'Oats',
#   'Price': 180,
#   'Quantity': 100,
#   'Company': 'Quaker Oats',
#   'Best Before': '6 months'},
#  '303': {'Name': 'Diary Milk',
#   'Price': 20,
#   'Quantity': 200,
#   'Company': 'Cadbury',
#   'Best Before': '5 months'},
#  '304': {'Name': 'Peanut butter',
#   'Price': 300,
#   'Quantity': 100,
#   'Company': 'Pintola',
#   'Best Before': '5 months'},
#  '305': {'Name': 'Milk Powder',
#   'Price': 30,
#   'Quantity': 25,
#   'Company': 'Amul',
#   'Best Before': '2 months'},
#  '306': {'Name': '50-50',
#   'Price': 10,
#   'Quantity': 50,
#   'Company': 'Parle',
#   'Best Before': '5 months'},
#  '307': {'Name': 'Gulab Jamun',
#   'Price': 20,
#   'Quantity': 20,
#   'Company': 'MTR',
#   'Best Before': 'NA'},
#  '308': {'Name': 'Kulfi',
#   'Price': 20,
#   'Quantity': 30,
#   'Company': 'Nestle',
# ...

# %% [markdown]
# # Viewing the products

# %%
file = open("record.json",'r')
r = file.read()
file.close()
record = json.loads(r)

# %%
print("#####################################################\n")
print("Product ID".center(15)+"PRODUCT NAME".center(25)+"\n")
print("#####################################################\n")
for i in record:
  print(str(i).center(15) +"\t"+ str(record[i]['Name']).center(25) )
# Out:
# #####################################################
#
#    Product ID         PRODUCT NAME
#
# #####################################################
#
#       301      	         Horlicks
#       302      	           Oats
#       303      	        Diary Milk
#       304      	      Peanut butter
#       305      	       Milk Powder
#       306      	          50-50
#       307      	       Gulab Jamun
#       308      	          Kulfi
#       309      	         Bourbon
#       310      	        Krackjack
#       311      	        Milky Bar
#       312      	           Milo
#       313      	         Kit Kat
#       314      	          Nestea
#       315      	         Sunfeast
#       316      	          20-20
#       317      	          Marie
#       318      	         FullToss
#       319      	          kismi
#       320      	         Poppins
#       321      	       Cattle Feed
#       322      	        Panchamrit
#       323      	       Happy Treats
# ...

# %%
ui_prod=str(input('Enter the product ID of the product: '))
ui_quant=int(input('Enter the quantinty of the product: '))


print('############ PURCHASE SUMMARY ############')
print('Product Name:          ',record[ui_prod]['Name'])
print('Price (per quantity):  ',record[ui_prod]['Price'])
print('Total Amount :         ',record[ui_prod]['Price']*ui_quant)
print('###########################################')





record[ui_prod]['Quantity'] =record[ui_prod]['Quantity']-ui_quant
# Out:
# Enter the product ID of the product: 316
# Enter the quantinty of the product: 3
# ############ PURCHASE SUMMARY ############
# Product Name:           20-20
# Price (per quantity):   10
# Total Amount :          30
# ###########################################

# %% [markdown]
# # Update the inventory after purchase

# %%
js = json.dumps(record)

fd =open('record.json','w')
fd.write(js)
fd.close
# Out:
# <function TextIOWrapper.close()>

# %%
js
# Out:
# '{"301": {"Name": "Horlicks", "Price": 200, "Quantity": 100, "Company": "Unilever", "Best Before": "5 months"}, "302": {"Name": "Oats", "Price": 180, "Quantity": 100, "Company": "Quaker Oats", "Best Before": "6 months"}, "303": {"Name": "Diary Milk", "Price": 20, "Quantity": 200, "Company": "Cadbury", "Best Before": "5 months"}, "304": {"Name": "Peanut butter", "Price": 300, "Quantity": 100, "Company": "Pintola", "Best Before": "5 months"}, "305": {"Name": "Milk Powder", "Price": 30, "Quantity": 25, "Company": "Amul", "Best Before": "2 months"}, "306": {"Name": "50-50", "Price": 10, "Quantity": 50, "Company": "Parle", "Best Before": "5 months"}, "307": {"Name": "Gulab Jamun", "Price": 20, "Quantity": 20, "Company": "MTR", "Best Before": "NA"}, "308": {"Name": "Kulfi", "Price": 20, "Quantity": 30, "Company": "Nestle", "Best Before": "NA"}, "309": {"Name": "Bourbon", "Price": 10, "Quantity": 20, "Company": "Britania", "Best Before": "5 months"}, "310": {"Name": "Krackjack", "Price": 10
# ...

# %% [markdown]
# # Sales and Billing

# %%
sales={}
sale_id = 0

# %%
import time
while(True):
  file = open("record.json",'r')
  r = file.read()
  file.close()
  id = str(input("Enter the product id: "))
  if (id in record):
    pass
  else:
    print("Invalid ID")
    print("\n")
    continue
  print("\nProduct name :",record[id]['Name'])
  price = int(record[id]['Price'])
  print("Price :",record[id]['Price'])
  quantity = int(input("\nEnter quantity: "))
  if (quantity > (record[id]['Quantity'])):
    print("\nStock Not Available")
    print("Available stock :", record[id]['Quantity'])
    print("\n")
  else:
    total_price =  price*quantity
    print("TOTAL AMOUNT :",total_price)
    purchased_quantity = quantity
    quantity = int(record[id]['Quantity']) - quantity
    record[id]['Quantity'] = quantity
    sale_id = sale_id+1
    sales[sale_id] = {"Product ID":id, "Name":str(record[id]['Name']),"Quantity":str(purchased_quantity),"Price":total_price}
    sale = json.dumps(sales)
    file = open("sales.json",'w')
    file.write(sale)
    file.close()
    print("\n________________________________________________________________________\n")
    print("\n****************************BILL RECIEPT*********************************")
    print("\n________________________________________________________________________ \n")
    print("Product ID".center(15)+"PRODUCT NAME".center(25)+"QUANTITY".center(15)+"PRICE".center(15))
    print("\n-----------------------------------------------------------------------")
    print(str(id.center(15)) + str(record[id]['Name']).center(25) + str(purchased_quantity).center(15) + str(total_price).center(15) )
    print("\n------------------------------------------------------------------------")
    print("TOTAL PRICE".center(55)+str(total_price).center(15))
    print("\n------------------------------------------------------------------------")
    print("Date:",time.ctime())
    print("\n________________________________________________________________________\n")
    print("\n*************************THANK YOU,VISIT AGAIN**************************")
    
    print("\n*****************************THE MEGA STORE*****************************")
    print("\n________________________________________________________________________\n")
    print("\n")
    break
# Out:
# Enter the product id: 316
#
# Product name : 20-20
# Price : 10
#
# Enter quantity: 3
# TOTAL AMOUNT : 30
#
# ________________________________________________________________________
#
#
# ****************************BILL RECIEPT*********************************
#
# ________________________________________________________________________
#
#    Product ID         PRODUCT NAME          QUANTITY        PRICE
#
# -----------------------------------------------------------------------
#       316                20-20                 3              30
#
# ------------------------------------------------------------------------
#                       TOTAL PRICE                             30
#
# ------------------------------------------------------------------------
# Date: Fri Sep 10 11:08:40 2021
#
# ________________________________________________________________________
#
#
# *************************THANK YOU,VISIT AGAIN**************************
#
# ...

# %% [markdown]
# # Sales Report

# %%
import json
file = open("sales.json",'r')
r = file.read()
file.close()
record = json.loads(r)
print("◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻\n")
print("Product ID".center(15)+"PRODUCT NAME".center(25)+"PURCHASED QUANTITY".center(25)+"PURCHASED PRICE".center(25)+"\n")

print("◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻\n")
sum = 0
for i in record:
  print(str(i).center(15) + str(record[i]['Name']).center(25) + str(record[i]['Quantity']).center(25) + str(record[i]['Price']).center(25) )
  sum = sum + record[i]['Price']
print("__________________________________________________________________________________________\n")
print("Total Sales Price".center(65)+str(sum).center(25))
print("__________________________________________________________________________________________\n")
# Out:
# ◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻
#
#    Product ID         PRODUCT NAME          PURCHASED QUANTITY        PURCHASED PRICE
#
# ◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻◻
#
#        1                 20-20                      3                        30
# __________________________________________________________________________________________
#
#                         Total Sales Price                                    30
# __________________________________________________________________________________________
